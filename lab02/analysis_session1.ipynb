# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

n_channel = [437, 337, 810]
n_channel_FWHM = [55, 48, 10]
E_peak = [662, 511, 1275]

results = linregress(n_channel, E_peak)
print(results)

y = lambda x: results[0]*x+results[1]

plt.figure(figsize = (10,10))
plt.errorbar(n_channel, E_peak, xerr = n_channel_err, fmt = 'k+', capsize = 5)
plt.plot(np.linspace(200, 900, 2), y(np.linspace(200, 900, 2)), 'r-')
# Out:
# LinregressResult(slope=1.6229261541927489, intercept=-40.90500941377138, rvalue=0.9998985444067967, pvalue=0.0090685278257037, stderr=0.023119838837505804)
